# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys


df = pd.read_csv('athlete_events.csv')
dr = pd.read_csv('rd1.csv')	
# print(df)

a2 = df[df['Season']=='Summer']
a2.to_csv("summer.csv",index = False)
ds = pd.read_csv('summer.csv')
#print(ds)

a3 = df[df['Season']=='Winter']
a3.to_csv('winter.csv', index = False)
dw = pd.read_csv('winter.csv')
#print(dw)

# %%
city_to_country = {'Mexico City':'Mexico' ,
                   'Berlin':'Germany',
                   'Munich':'Germany',
                   'Garmisch-Partenkirchen':'Germany',
                   'Montreal':'Canada',
                   'Calgary':'Canada',
                   'Vancouver':'Canada',
                  'Stockholm':'Sweden',
                  'Moskva':'Russia',
                   'Sochi':'Russia',
                   'St. Louis':'USA',
                   'Lake Placid':'USA',
                   'Los Angeles':'USA',
                   'Atlanta':'USA',
                  'Squaw Valley':'USA',
                   'Salt Lake City':'USA',
                   'Seoul':'South Korea' ,
                  'Barcelona':'Spain' ,
                  'Helsinki':'Finland',
                  'Innsbruck':'Austria' ,
                  'Melbourne':'Australia',
                  'Sydney':'Australia',
                   'Athina':'Greece' ,
                  'Beijing':'China' ,
                  'Antwerpen':'Belgium',
                  "Cortina d'Ampezzo":'Italy',
                   'Roma':'Italy',
                   'Torino':'Italy',
                  'London':'UK',
                  'Amsterdam':'Netherlands',
                  'Tokyo':'Japan',
                   'Sapporo':'Japan',
                   'Nagano':'Japan',
                   'Oslo':'Norway',
                   'Lillehammer':'Norway',
                  'Sarajevo':'Yugoslavia' ,
                  'Sankt Moritz':'Switzerland',
                   'Paris':'France',
                   'Chamonix':'France',
                   'Albertville':'France',
                   'Grenoble':'France',
                  'Rio de Janeiro':'Brazil'}

# %%
ds["Country_Host"]=ds["City"].map(city_to_country)

# %%
ds = pd.concat([ds,pd.get_dummies(df.Medal)],axis=1)
ds['allmedals']= ds['Bronze'] + ds['Gold'] + ds['Silver']

# %%
y = ds[ds.Year == 2008]
y
# Out:
#               ID                                               Name Sex   Age  \
# 33          21.0                          Ragnhild Margrethe Aamodt   F  27.0
# 74          49.0                                       Moonika Aava   F  28.0
# 97          63.0                                Jos Luis Abajo Gmez   M  30.0
# 101         67.0            Mariya Vasilyevna Abakumova (-Tarabina)   F  22.0
# 105         69.0                                  Tamara Abalde Daz   F  19.0
# 110         72.0                   Aleksey Aleksandrovich Abalmasov   M  28.0
# 111         73.0                                          Luc Abalo   M  23.0
# 136         92.0                                      Ignazio Abate   M  21.0
# 138         93.0                                     Jol Marc Abati   M  38.0
# 190        127.0                                     Shakeel Abbasi   M  24.0
# 193        129.0                                     Ruslan Abbasov   M  22.0
# 194        130.0                                      Tural Abbasov   M  18.0
# 208        143.0                               Desmond "Des" Abbott   M  21.0
# 209        144.0                              Geoffrey Grant Abbott   M  23.0
# 212        148.0                             Kathryn "Katie" Abbott   F  21.0
# 217        153.0                              Monica Cecilia Abbott   F  23.0
# 218        154.0                                    Khadija Abbouda   F  40.0
# 222        156.0                               Mahmoud Abd El-Kader   M  23.0
# 224        157.0                       Mohamed Ibrahim Abd El-Salam   M  26.0
# 225        158.0                                      Noha Abd Rabo   F  21.0
# 222538               Sailing Men's Two Person Keelboat     NaN        China
#
#         Bronze  Gold  Silver  allmedals
# 33           0     0       0          0
# 74           0     0       0          0
# 97           0     0       0          0
# 101          0     0       0          0
# 105          1     0       0          1
# 110          1     0       0          1
# 111          0     0       0          0
# 136          0     0       0          0
# 138          0     0       0          0
# 190          0     0       0          0
# 193          0     0       0          0
# 194          0     0       0          0
# 208          0     0       1          1
# 209          0     0       0          0
# 212          0     0       0          0
# 217          0     0       0          0
# 218          0     1       0          1
# 222          0     1       0          1
# 224          0     0       0          0
# 225          0     0       0          0
# 226          0     1       0          1
# 227          0     1       0          1
# 229          0     0       0          0
# 289          0     0       0          0
# 296          0     0       0          0
# 315          0     0       0          0
# 316          0     0       0          0
# 338          0     0       0          0
# 352          0     0       0          0
# 355          0     0       0          0
# ...        ...   ...     ...        ...
# 222168       0     0       0          0
# 222169       0     0       0          0
# 222189       0     0       0          0
# 222194       0     0       0          0
# 222197       0     0       0          0
# 222198       0     0       0          0
# 222215       0     0       0          0
# 222216       0     0       0          0
# 222217       0     0       0          0
# 222218       0     0       0          0
# 222223       0     0       0          0
# 222300       0     0       0          0
# 222360       0     0       0          0
# 222379       0     0       0          0
# 222380       0     0       0          0
# 222386       0     0       0          0
# 222391       0     0       0          0
# 222392       0     0       0          0
# 222405       0     0       0          0
# 222427       0     0       0          0
# 222429       0     0       0          0
# 222430       0     0       0          0
# 222431       0     0       0          0
# 222432       0     0       0          0
# 222454       0     0       0          0
# 222468       0     0       0          0
# 222469       0     0       0          0
# 222498       0     0       0          0
# 222502       0     0       0          0
# 222538       0     0       0          0
#
# [13602 rows x 20 columns]

# %%
host_city = y['City'].unique()
host_city
# Out:
# array(['Beijing'], dtype=object)

# %%
n_sports = y['Sport'].nunique()
n_sports
# Out:
# 34

# %%
n_events = y['Event'].nunique()
n_events
# Out:
# 302

# %%
n_parts = y['Name'].nunique()
n_parts
# Out:
# 10880

# %%
noc = y.groupby(['Team'], as_index = True).agg({'Medal':'count'})
maxmedals = noc.sort_values(['Medal'], ascending = False)
maxmedals = maxmedals.reset_index()
top_c = maxmedals.head(5)
top_c
# Out:
#             Team  Medal
# 0  United States    309
# 1          China    170
# 2      Australia    149
# 3         Russia    142
# 4        Germany     96

# %%
labels = top_c.Team
sizes = top_c.Medal
explode = (0.1, 0, 0, 0, 0)  
colors =  ['gold','silver','brown','green','teal']
plt.pie(sizes, explode=explode, labels=labels,colors= colors, autopct='%1.1f%%',shadow=True, startangle=90)
plt.axis('equal') 
plt.title("Countries Dominating the Given Year")
# Out:
# Text(0.5,1,'Countries Dominating the Given Year')

# %%
y1 = y[['Name','Team','Medal']]
y1 =y.groupby(['Name','Team']).agg({'Medal':'count'}).sort_values('Medal', ascending = False)
y1 = y1.reset_index()

top_p = y1.head(5)
top_p
# Out:
#                                         Name           Team  Medal
# 0                    Michael Fred Phelps, II  United States      8
# 1              Natalie Anne Coughlin (-Hall)  United States      6
# 2      Anastasiya Valeryevna "Nastia" Liukin  United States      5
# 3               Shawn Machel Johnson (-East)  United States      4
# 4  Lisbeth Constance "Libby" Lenton-Trickett      Australia      4

# %%
objects = top_p.Name
y_pos = np.arange(len(objects))
performance = top_p.Medal

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects, rotation = 20)
plt.xlabel('Players')
plt.ylabel('Medal Count')
plt.title('Top 5 Athletes of Given Year')
 
plt.show()

# %%
sr = y.groupby('Sex').agg({'Sex':'count'})
sr = sr.rename(columns={'Sex': 'Total'})
sr =sr.reset_index()
sr
# Out:
#   Sex  Total
# 0   F   5816
# 1   M   7786

# %%
#DONUT M VS F

plt.pie(sr.Total, labels= ('Female','Male'), autopct = '%1.1f%%', colors=['blue','silver'], shadow= True)
p=plt.gcf()
my_circle=plt.Circle( (0,0), 0.7, color='white')
p.gca().add_artist(my_circle)
plt.title('Gender Distribution for Given Year')
plt.show()

# %%
y.head()
# Out:
#        ID                                     Name Sex   Age  Height  Weight  \
# 33   21.0                Ragnhild Margrethe Aamodt   F  27.0   163.0     NaN
# 74   49.0                             Moonika Aava   F  28.0   168.0    65.0
# 97   63.0                      Jos Luis Abajo Gmez   M  30.0   194.0    87.0
# 101  67.0  Mariya Vasilyevna Abakumova (-Tarabina)   F  22.0   179.0    80.0
# 105  69.0                        Tamara Abalde Daz   F  19.0   185.0    72.0
#
#         Team  NOC        Games    Year  Season     City       Sport  \
# 33    Norway  NOR  2008 Summer  2008.0  Summer  Beijing    Handball
# 74   Estonia  EST  2008 Summer  2008.0  Summer  Beijing   Athletics
# 97     Spain  ESP  2008 Summer  2008.0  Summer  Beijing     Fencing
# 101   Russia  RUS  2008 Summer  2008.0  Summer  Beijing   Athletics
# 105    Spain  ESP  2008 Summer  2008.0  Summer  Beijing  Basketball
#
#                                Event   Medal Country_Host  Bronze  Gold  \
# 33         Handball Women's Handball    Gold        China       0     0
# 74   Athletics Women's Javelin Throw     NaN        China       0     0
# 97    Fencing Men's epee, Individual  Bronze        China       0     0
# 101  Athletics Women's Javelin Throw  Silver        China       0     0
# 105    Basketball Women's Basketball     NaN        China       1     0
#
#      Silver  allmedals
# 33        0          0
# 74        0          0
# 97        0          0
# 101       0          0
# 105       0          1

# %%
# Extract year, host nation and team name from the data
#yht = y.groupby(['Team','Country_Host','Bronze','Silver','Gold']).agg({'allmedals':'sum'}).reset_index()
host_team = y[y.Team == y.Country_Host]
host_team
# Out:
#               ID             Name Sex   Age  Height  Weight   Team  NOC  \
# 7231      4639.0     Ao Changrong   M  25.0   173.0    71.0  China  CHN
# 10738     6857.0          Bai Xue   F  19.0   165.0    53.0  China  CHN
# 11963     7595.0      Bao Chunlai   M  25.0   190.0    80.0  China  CHN
# 11965     7597.0     Bao Yingying   F  24.0   172.0    67.0  China  CHN
# 11966     7597.0     Bao Yingying   F  24.0   172.0    67.0  China  CHN
# 17844    11224.0           Bi Yan   F  24.0   170.0    62.0  China  CHN
# 17863    11237.0     Bian Hongmin   M  18.0   210.0    95.0  China  CHN
# 17866    11239.0         Bian Lan   F  21.0   180.0    73.0  China  CHN
# 25780    15958.0           Bu Tao   M  25.0   180.0    86.0  China  CHN
# 32976                     Athletics Men's Javelin Throw     NaN        China
# 32978              Modern Pentathlon Women's Individual     NaN        China
# 32989                             Hockey Women's Hockey  Silver        China
# 32992                           Diving Women's Platform    Gold        China
# ...                                                 ...     ...          ...
# 221288                        Fencing Men's Sabre, Team     NaN        China
# 221296                            Diving Men's Platform  Silver        China
# 221301         Canoeing Men's Kayak Fours, 1,000 metres     NaN        China
# 221330                    Volleyball Women's Volleyball  Bronze        China
# 221335                            Hockey Women's Hockey  Silver        China
# 221336                          Handball Men's Handball     NaN        China
# 221343            Swimming Women's 100 metres Butterfly     NaN        China
# 221344     Swimming Women's 4 x 100 metres Medley Relay  Bronze        China
# 221346                     Athletics Women's Pole Vault     NaN        China
# 221348                        Softball Women's Softball     NaN        China
# 221351                        Rowing Men's Coxed Eights     NaN        China
# 221367                      Basketball Men's Basketball     NaN        China
# 221370                     Taekwondo Men's Welterweight  Bronze        China
# 221375                          Handball Men's Handball     NaN        China
# 221378                   Fencing Men's Foil, Individual     NaN        China
# 221387            Swimming Women's 200 metres Freestyle     NaN        China
# 221388  Swimming Women's 4 x 200 metres Freestyle Relay  Silver        China
# 221392              Shooting Men's Air Rifle, 10 metres  Silver        China
# 221404                          Football Men's Football     NaN        China
# 221407                          Handball Men's Handball     NaN        China
# 221408                       Athletics Women's Marathon     NaN        China
# 221410      Athletics Women's 3,000 metres Steeplechase     NaN        China
# 221418             Swimming Women's 50 metres Freestyle     NaN        China
# 221419            Swimming Women's 100 metres Freestyle     NaN        China
# 221420  Swimming Women's 4 x 100 metres Freestyle Relay     NaN        China
# 222058           Gymnastics Men's Individual All-Around     NaN        China
# 222059                 Gymnastics Men's Team All-Around    Gold        China
# 222060                  Gymnastics Men's Floor Exercise    Gold        China
# 222061                  Gymnastics Men's Horizontal Bar    Gold        China
# 222067                     Boxing Men's Light-Flyweight    Gold        China
#
#         Bronze  Gold  Silver  allmedals
# 7231         0     0       0          0
# 10738        1     0       0          1
# 11963        0     0       0          0
# 11965        0     0       0          0
# 11966        0     0       0          0
# 17844        0     0       0          0
# 17863        0     0       0          0
# 17866        0     0       0          0
# 25780        0     0       0          0
# 27886        0     0       0          0
# 27887        0     0       0          0
# 27893        0     0       0          0
# 29116        1     0       0          1
# 29128        0     0       0          0
# 29137        0     0       0          0
# 32159        0     0       0          0
# 32217        0     0       0          0
# 32900        0     1       0          1
# 32908        0     0       0          0
# 32915        1     0       0          1
# 32928        0     0       0          0
# 32930        0     1       0          1
# 32944        0     0       0          0
# 32955        0     0       0          0
# 32956        0     0       0          0
# 32971        0     0       0          0
# 32976        0     0       0          0
# 32978        0     1       0          1
# 32989        0     0       1          1
# 32992        0     0       0          0
# ...        ...   ...     ...        ...
# 221288       0     0       0          0
# 221296       0     0       0          0
# 221301       0     0       0          0
# 221330       0     0       0          0
# 221335       0     0       0          0
# 221336       0     0       0          0
# 221343       0     0       0          0
# 221344       0     0       0          0
# 221346       0     0       0          0
# 221348       0     0       0          0
# 221351       0     0       0          0
# 221367       0     0       0          0
# 221370       0     0       0          0
# 221375       0     0       0          0
# 221378       0     1       0          1
# 221387       0     0       0          0
# 221388       0     0       0          0
# 221392       0     0       0          0
# 221404       0     0       0          0
# 221407       0     0       0          0
# 221408       0     0       0          0
# 221410       0     0       0          0
# 221418       0     0       0          0
# 221419       0     0       0          0
# 221420       0     0       0          0
# 222058       1     0       0          1
# 222059       0     0       0          0
# 222060       0     0       0          0
# 222061       1     0       0          1
# 222067       0     0       0          0
#
# [708 rows x 20 columns]

# %%
h_sports = host_team['Sport'].nunique()
h_sports
# Out:
# 34

# %%
h_events = host_team['Event'].nunique()
h_events
# Out:
# 252

# %%
h_t = host_team['Name'].nunique()
h_t
# Out:
# 567

# %%
# h_m = host_team[host_team.Sex == 'M']

# h_m['Name'].nunique()

# %%
# h_f= host_team[host_team.Sex == 'F']
# h_f['Name'].nunique()

# %%
h_mc = host_team['Medal'].count()
h_mc
# Out:
# 170

# %%
h_medals = host_team.groupby('Sport').agg({'Medal':'count'}).sort_values('Medal',ascending = False).reset_index()
#h_medals = h_medals.dropna()
#h_medals = h_medals.loc[~(h_medals==0).all(axis=)]

#h_medalsdf=h_medals.dropna(how='all',axis=0)


h_m = h_medals[h_medals.Medal<1]
h_medals = h_medals.drop(h_m.index, axis =0)

h_medals= h_medals.head(5)

# %%
sns.countplot(h_medals['Medal'])

plot1 = sns.barplot('Sport','Medal',data=h_medals).set_xticklabels(h_medals.Sport,rotation=82)

plt.xlabel('Sports')

plt.ylabel('No of Medals Won')
           
           
           
plt.title('Age at which aplayer has won most number of Medals for the given Sport')
# Out:
# Text(0.5, 1.0, 'Age at which aplayer has won most number of Medals for the given Sport')

# %%
host_team = host_team[['Name','Team','Medal']]
h_t1 =host_team.groupby(['Name','Team']).agg({'Medal':'count'}).sort_values('Medal', ascending = False)
h_t1 = h_t1.reset_index()

top_p = h_t1.head(5)
top_p
# Out:
#            Name   Team  Medal
# 0       Zou Kai  China      3
# 1      Yang Wei  China      3
# 2    Yang Yilin  China      3
# 3     Cheng Fei  China      3
# 4  Pang Jiaying  China      3

# %%
objects = top_p.Name
y_pos = np.arange(len(objects))
performance = top_p.Medal

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects, rotation = 90)
plt.xlabel('Players')
plt.ylabel('Medal Count')
plt.title('Top 5 Athletes Host country')
# Out:
# Text(0.5, 1.0, 'Top 5 Athletes of Given Year')

# %%
fig = plt.figure(figsize=(10,10))

plt.subplot(2, 2, 1)

labels = top_c.Team
sizes = top_c.Medal
explode = (0.1, 0, 0, 0, 0)  
colors =  ['gold','silver','brown','green','teal']
plt.pie(sizes, explode=explode, labels=labels,colors= colors, autopct='%1.1f%%',shadow=True, startangle=90)
plt.axis('equal') 
plt.title("Top Countries")




plt.subplot(2, 2, 2)

plt.pie(sr.Total, labels= ('Female','Male'), autopct = '%1.1f%%', colors=['blue','silver'], shadow= True)
p=plt.gcf()
my_circle=plt.Circle( (0,0), 0.7, color='white')
p.gca().add_artist(my_circle)
plt.title('Gender Distribution')


plt.subplot(2, 2, 3)
sns.countplot(h_medals['Medal'])

plot1 = sns.barplot('Sport','Medal',data=h_medals).set_xticklabels(h_medals.Sport,rotation=82)

plt.xlabel('Sports')
plt.ylabel('No of Medals Won')
plt.title('Host COuntry Top Sports')


plt.subplot(2, 2, 4)

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects, rotation = 90)
plt.xlabel('Players')
plt.ylabel('Medal Count')
plt.title('Top 5 Athletes Host country')

plt.show()

# %%
# y[['Year', 'City']].drop_duplicates().sort_values('Year')

# y.loc[:, ['Year', 'Country_Host']].drop_duplicates().sort_values('Year')

# # Extract year, host nation and team name from the data
# year_host_team = y[['Year', 'Country_Host', 'Team']].drop_duplicates()

# # check rows where host country is the same as team
# row_mask_4 = (year_host_team['Country_Host'] == year_host_team['Team'])

# # add years in the year_host_team to capture one previous and one later year
# year_host_team['Prev_Year'] = year_host_team['Year'] - 4
# year_host_team['Next_Year'] = year_host_team['Year'] + 4

# # Subset only where host nation and team were the same
# year_host_team = year_host_team[row_mask_4]
# year_host_team.reset_index()

# year_host_team = year_host_team.rename(columns={'Year': 'Host_year'})

# # Calculate the medals won in each year where a team played at home. merge year_host_team with medal_tally on year and team
# # year_host_team_medal = year_host_team.merge(maxmedals,
# #                                            left_on = [year_host_team.Host_year, year_host_team.Team],
# #                                            right_on = [year_host_team.Host_year, year_host_team.Team],
# #                                            how = 'left')

# # year_host_team_medal = year_host_team.merge(maxmedals,
# #                                            left_on = ['Team'],
# #                                            right_on = ['Team'],
# #                                            how = 'left')

# year_host_team_medal.rename(columns = {'maxmedals' : 'Medal_Won_Host_Year'}, inplace = True)

# # Calculate medals won by team in previous year
# # year_host_team_medal = year_host_team_medal.merge(maxmedals,
# #                                                  left_on = ['Prev_Year', 'Team'],
# #                                                  right_on = ['Year', 'Team'],
# #                                                  how = 'left')

# # year_host_team_medal.drop('Year_y', axis = 1, inplace = True)
# # year_host_team_medal.rename(columns = {'Medal_Won_Corrected': 'Medal_Won_Prev_Year',
# #                                       'Year_x':'Year'}, inplace = True)

# # # Calculate the medals won by the team the year after they hosted.
# # year_host_team_medal = year_host_team_medal.merge(maxmedals,
# #                                                  left_on = ['Next_Year', 'Team'],
# #                                                  right_on = ['Year', 'Team'],
# #                                                  how = 'left')

# # year_host_team_medal.drop('Year_y', axis = 1, inplace = True)s
# # year_host_team_medal.rename(columns = {'Year_x': 'Year',
# #                                       'Medal_Won_Corrected' : 'Medal_Won_Next_Year'}, inplace = True)

# # # General formatting changes
# # year_host_team_medal.drop(['Prev_Year', 'Next_Year'], axis = 1, inplace = True)
# # year_host_team_medal.sort_values('Year', ascending = True, inplace = True)
# # year_host_team_medal.reset_index(inplace = True, drop = True)

# # # column re-ordering
# # year_host_team_medal = year_host_team_medal.loc[:, ['Year', 'Country_Host', 'Team', 'Medal_Won_Prev_Year', 'Medal_Won_Host_Year', 'Medal_Won_Next_Year']]

# year_host_team
# Out:
#       Host_year Country_Host   Team  Prev_Year  Next_Year
# 7231     2008.0        China  China     2004.0     2012.0
